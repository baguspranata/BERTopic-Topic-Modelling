# %%
# !pip install bertopic
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import nltk
nltk.download('stopwords')
nltk.download('punkt')
import pandas as pd
import numpy as np
from bertopic import BERTopic
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import re
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
import re

# Load the Excel file and extract the text data
data = pd.read_excel('practice7.xlsx')
text_data = data['Text'].astype(str).tolist()

# %%
from bertopic import BERTopic
from transformers.pipelines import pipeline
from transformers import AutoTokenizer
from sentence_transformers import SentenceTransformer

model_path = "indolem/indobert-base-uncased"
sentence_model = SentenceTransformer(model_path)
# Out:
# WARNING:sentence_transformers.SentenceTransformer:No sentence-transformers model found with name /root/.cache/torch/sentence_transformers/indolem_indobert-base-uncased. Creating a new one with MEAN pooling.
# Some weights of the model checkpoint at /root/.cache/torch/sentence_transformers/indolem_indobert-base-uncased were not used when initializing BertModel: ['cls.predictions.transform.LayerNorm.bias', 'cls.predictions.decoder.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.bias', 'cls.predictions.transform.dense.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.dense.weight']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# ...

# %%
text_data = [str(doc) for doc in text_data]
topic_model = BERTopic(embedding_model=sentence_model, verbose=True).fit(text_data)
# Out:
# Batches:   0%|          | 0/1456 [00:00<?, ?it/s]
# 2023-05-08 03:15:46,543 - BERTopic - Transformed documents to Embeddings
# 2023-05-08 03:18:01,511 - BERTopic - Reduced dimensionality
# 2023-05-08 03:18:08,874 - BERTopic - Clustered reduced embeddings

# %%
topic_model.get_topic_info().head(10)
# Out:
#    Topic  Count                           Name
# 0     -1  13890        -1_halo_kak_sampai_saya
# 1      0   7125                  0_09_08_07_06
# 2      1   3138         1_update_ada_nya_kurir
# 3      2    926                2_nan_bik_rm_au
# 4      3    716        3_tapi_saya_kalo_barang
# 5      4    676  4_tkp01_bac0t_4fc2c8f_kewvpk8
# 6      5    546            5_ja_jelas_di_cepat
# 7      6    525               6_ok_min_oky_kec
# 8      7    472        7_halo_putra_kak_kelvin
# 9      8    369        8_jan_ghazali_muhammad_

# %%
# Get topics and their corresponding keywords
topics = topic_model.get_topics()

# Display topics and their keywords
for topic, keywords in topics.items():
    if topic != -1:
        print(f"Topic {topic}:")
        print(", ".join([word for word, _ in keywords]))
        print()
# Out:
# Topic 0:
# 09, 08, 07, 06, 17, 19, 18, 16, 11, 14
#
# Topic 1:
# update, ada, nya, kurir, ga, aja, gak, bisa, udah, yg
#
# Topic 2:
# nan, bik, rm, au, ah, no, , , ,
#
# Topic 3:
# tapi, saya, kalo, barang, sudah, di, ini, tp, pesan, bisa
#
# Topic 4:
# tkp01, bac0t, 4fc2c8f, kewvpk8, e181nnh, gfg774l, 4xppjly, 64djw2m, gn474mk, gcd3ufj
#
# Topic 5:
# ja, jelas, di, cepat, saya, kirim, alamat, sudah, kurir, bantu
#
# Topic 6:
# ok, min, oky, kec, segera, , , , ,
#
# Topic 7:
# halo, putra, kak, kelvin, ika, saputri, dewa, gumilang, sitanggang, silaen
#
# Topic 8:
# jan, ghazali, muhammad, , , , , , ,
#
# Topic 9:
# jan, , , , , , , , ,
#
# Topic 10:
# 30, jan, begini, boleh, 10, kak, , , ,
#
# Topic 11:
# 13, jan, , , , , , , ,
#
# Topic 12:
# sebagai, penyedia, tokopedia, blm, sampai2, criss, layanan, cross, oleh, paket
#
# Topic 13:
# 12, jan, , , , , , , ,
#
# Topic 14:
# 31, jan, , , , , , , ,
#
# Topic 15:
# , , , , , , , , ,
#
# Topic 16:
# ...

# %%
topic_model.visualize_topics()

#Here's a brief explanation of the Intertopic Distance Map visualization:

#Each point on the map represents a topic. 
#The position of the points in the 2D space reflects the similarity between topics.
#Points that are closer together represent topics that are more similar, 
#while points that are farther apart represent topics that are more dissimilar.
#The visualization is interactive, allowing you to hover over each point to see the 
#top words for the corresponding topic. 

#This can help you understand the nature of the topic and the semantic similarity 
#between topics based on the words they share.
#In summary, the Intertopic Distance Map provides an overview of the relationships 
#between the topics in your dataset, 
#allowing you to identify clusters of similar topics and spot any outliers.
#This can be useful for understanding the structure of the data and 
#the distribution of topics in the analyzed corpus.
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
topic_model.visualize_barchart()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
